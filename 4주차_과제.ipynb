# %% [markdown]
# <a href="https://colab.research.google.com/github/0-ROK/ai.gitct-pre-course/blob/master/4%EC%A3%BC%EC%B0%A8_%EA%B3%BC%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 4주차 과제
# - 용어 정리
# - 딥러닝 강의 클론 코딩
# - 딥러닝 순전파 & 역전파 계산

# %% [markdown]
# ## 1. 용어 정리
#
# 다음 제시된 단어의 정의(설명)를 정리하여 작성 하세요.
#
# * 2문장 이상 작성 해 주세요.
# * 주제(단어)와 크게 벗어나지만 않는다면 정답처리 됩니다.
# * 강의 뿐 아니라 기타 레퍼런스를 참고하여 작성하셔도 됩니다. (기타 레퍼런스를 참고하신 경우, 해당 레퍼런스를 정리하여 하단에 작성해 주세요.)

# %% [markdown]
# __(예시)__
# ### 심층 신경망
# : 입력층과 출력층 사이에 여러 개의 은닉층들로 이뤄진 인공신경망이다. 심층 신경망은 일반적으로 인공신경망과 마찬가지로 복잡한 비선형 관계들을 모델링 할 수 있다. 신층신경망의 목적은 분류 및 수치예측을 하기 위함이고 이미지 트레이닝이나 문자인식과 같은 분야에서 매우 유용하게 쓰이고 있다.

# %% [markdown]
# ### MCP 뉴런
# :워런 맥컬록(Warren McCulloch)과 월터 피츠(Walter Pitts)는 생물학적 뇌를 간소화하여 나타낸 모델이다.이들은 신경 세포를 이진 출력을 내는 간단한 논리 회로로 표현했다. 합쳐진 입력값이 임계값을 넘으면 축삭 돌기를 통해 출력값이 발생한다.
#
# ### 퍼셉트론
# :자동으로 최적의 가중치를 학습하는 알고리즘이다. 각 노드의 입력값과 가중치를 곱한 것들의 합이 임계치를 넘으면 뉴런이 출력값을 생성하게 된다.
#
# ### 역전파
# :딥러닝 알고리즘의 일종으로, 출력층과 지도 데이터의 오차를 이전 노드에게 다시 전달하여 가중치를 수정하는 알고리즘이다.
#
# ### 강화학습
# :강화학습은 에이전트가 현재의 상태에서 최고의 행동이 무엇인지 학습한다. 보상 함수는 에이전트가 행동을 할 때 보상을 제공하는데, 에이전트는 이 보상을 최대한 많이 받기 위해 모델을 학습해나간다.
#
# ### 과적합
# :인공지능 모델을 지나치게 학습하는 것을 말한다. 이 경우 오히려 현실 데이터의 예측능력이 떨어질 수 있다.
#
# ### 차원의 저주
# : 차원의 수가 늘어나면서 성능이 줄어드는 현상이다. 차원이 늘어나면서 개별 차원 내 학습 데이터가 감소하기 때문에 발생한다.
#
#
# https://datapedia.tistory.com/15

# %% [markdown]
# ## 2. 딥러닝 강의 클론 코딩
#
# ####__퍼셉트론 구조 구현하기__
# 딥러닝 강의(__딥러닝 원리[1] 3:15 ~ 5:15 부분__)를 보고 코드를 따라 치며 출력 결과를 만드세요.
#
#
# * 하나의 코드셀에 해당 코드를 한번에 다 적어서 실행해주세요 (__그렇게 하지 않을 경우, 아래 이미지와 같은 출력값이 나오지 않을 수 있습니다__)
#
# *__주의!__ 실제로 코딩해서 출력해보면 강의에 나온 출력 결과와 다르게 나옵니다!!

# %% [markdown]
# ![대체 텍스트](https://www.notion.so/image/https%3A%2F%2Fs3-us-west-2.amazonaws.com%2Fsecure.notion-static.com%2F0cceeed0-0235-4b0f-af88-0b8c377d5b4b%2F_2020-06-09__9.35.23.png?table=block&id=88fd8912-9356-49a4-9fda-a1a63fe96ea9&width=2870&cache=v2)

# %%
import tensorflow as tf
tf.compat.v1.set_random_seed(2020)
x = 0
y = 1
w = tf.random.normal([1],0,1)
b = tf.random.normal([1],0,1)

import math
def sigmoid(x):
  return 1/(1 + math.exp(-x))

for i in range(100001):
  output = sigmoid(x * w + 1 * b)
  error = y - output
  w = w + x* 0.1 * error
  b = b + 1 * 0.1 * error
  if i % 100 == 99:
    print("학습 횟수:",i, "Error:",error,"예측 결과:", output)
# Out:
# 학습 횟수: 99 Error: 0.09463240539328144 예측 결과: 0.9053675946067186
# 학습 횟수: 199 Error: 0.05020774581485887 예측 결과: 0.9497922541851411
# 학습 횟수: 299 Error: 0.03386821893903158 예측 결과: 0.9661317810609684
# 학습 횟수: 399 Error: 0.0254795475417523 예측 결과: 0.9745204524582477
# 학습 횟수: 499 Error: 0.020395445115306998 예측 결과: 0.979604554884693
# 학습 횟수: 599 Error: 0.016991321905264867 예측 결과: 0.9830086780947351
# 학습 횟수: 699 Error: 0.014555195462882198 예측 결과: 0.9854448045371178
# 학습 횟수: 799 Error: 0.01272677569558911 예측 결과: 0.9872732243044109
# 학습 횟수: 899 Error: 0.011304492845635505 예측 결과: 0.9886955071543645
# 학습 횟수: 999 Error: 0.01016688855289749 예측 결과: 0.9898331114471025
# 학습 횟수: 1099 Error: 0.009236441773085025 예측 결과: 0.990763558226915
# 학습 횟수: 1199 Error: 0.008461470609302357 예측 결과: 0.9915385293906976
# 학습 횟수: 1299 Error: 0.00780606622644997 예측 결과: 0.99219393377355
# 학습 횟수: 1399 Error: 0.007244592718303577 예측 결과: 0.9927554072816964
# 학습 횟수: 1499 Error: 0.006758243944009923 예측 결과: 0.9932417560559901
# ...

# %% [markdown]
# ## 3. 딥러닝 순전파 & 역전파 계산
#
# 딥러닝 강의(__딥러닝 원리[2] 0:55 ~ 4:32 부분__)에 나오는 순전파 & 역전파 계산에 대한 문제 입니다.
#
# 해당 영상과 다음 이미지를 참고하여 다음 2가지 물음에 답하세요.
#
#
# (1) 학습률이 0.2 일 경우 출력층의 노드값
#
# (2) 학습률이 0.1과 0.2 중 기대출력값이 지도데이터 "3"과 더 가까운 학습률은?

# %% [markdown]
# ![대체 텍스트](https://www.notion.so/image/https%3A%2F%2Fs3-us-west-2.amazonaws.com%2Fsecure.notion-static.com%2Ff54dfd45-92ec-44ae-9616-6949d2484a45%2F_2020-06-10__5.22.03.png?table=block&id=ee05da89-3ceb-4ad9-a2d3-c9f68d24d1d9&width=3580&cache=v2)

# %% [markdown]
# ## (1) 학습률이 0.2 일 경우 출력층의 노드값 : 1.6
# ## (2) 학습률이 0.1과 0.2 중 기대출력값이 지도데이터 "3"과 더 가까운 학습률은? : 기대출력값은 지도데이터와 일치한다. 따라서 지도데이터 "3"과 더 가까운 학습률은 존재하지 않는다.
